# %%
# import os 
# current_path = os.getcwd()
# print(current_path)

import os
import sys

cwd = os.getcwd()
module_path = os.path.abspath(cwd)
sys.path.insert(0, module_path)
from item import Item # in the case of a file named "item" and class named "Item"
#from phone import Phone



# Item.instantiate_from_csv()
# print(Item.all)


item1 = Item("MyItem", 750, 1)
item1.apply_increment(0.2)
item1.apply_discount()

print(item1.price)

item1.send_email()


#item1.name = "OtherItem"

# item1.name = "Otheritem3"
# print(item1.name)

# print(item1.read_only_name)

# item1.name = "AnotherItem3"
# print(item1.name)



#module_path = os.path.abspath(os.path.join('..'))

# if module_path not in sys.path:
#     sys.path.append(module_path) 


# from item import Item
# from phone import Phone


# from item import * 
# Item.calculate_total_price()


# Item.instantiate_from_csv()
# print(Item.all)

#/// notes pt 2 - inheritence  ///
      
# phone1 = Phone("phonev10", 500, 5)
# print(Item.all)
# print(Phone.all)

# phone1.broken_phones = 1
# phone2 = Phone("pvonev20", 700, 5)
# phone2.broken_phones = 1

# def placeholder():
#     print(Item.all)
#     print(Phone.all)

#     #/// notes pt 2 ///

#     item1 = Item("Phone", 100, 1) 
#     item2 = Item("Laptop", 1000, 3) 
#     # item3 = Item("Tablet", 1000, -1) 

#     print(Item.__dict__)
#     print(Item.pay_rate)
#     print(item1.calculate_total_price())
#     print(item2.calculate_total_price())
#     # print(item3.calculate_total_price())

#     #print(Item.price)
#     print("discounted item 1")
#     item1.apply_discount_instance_level()
#     print(item1.price)

#     print("Item 2 pay rate change")

#     item2.pay_rate = 0.7
#     item2.apply_discount_instance_level()
#     print(item2.price)
#     item2.price = 1000
#     item2.apply_discount_class_level()
#     print(item2.price)

#     for instance in Item.all:
#         print(instance.name)

#     print(Item.all)

#     Item.instantiate_from_csv()
#     print(Item.all)

#     print(Item.is_integer(7))
#     print(Item.is_integer(7.0))
#     print(Item.is_integer(7.5))

#     if 5.0 == 5:
#         print("float = int")

#     # Conventionally, statics are called as "Item.instantiate_from_csv" whereas classmethods are called like
#     # item1 = Item()
#     # item1.is_integer()
#     # item1.instantiate_from_something()
#     # from instance
# Out:
# 720.0
