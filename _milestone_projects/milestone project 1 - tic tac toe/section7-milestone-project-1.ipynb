# %%
# Visual representation
# User input
# Function
# Update variables
# New visual

def display(row1,row2,row3):
    print(row1)
    print(row2)
    print(row3)

row1 = [' ', ' ', ' ']
row2 = [' ', ' ', ' ']
row3 = [' ', ' ', ' ']

row2[1] = 'X'

display(row1, row2, row3)
# Out:
# [' ', ' ', ' ']
# [' ', 'X', ' ']
# [' ', ' ', ' ']

# %%
result = int(input(print("Choose index position: "))) #print is just so it displays "input" text inline for VSCode. 
print(result)
print(type(result))
# Out:
# Choose index position:
# ---------------------------------------------------------------------------
# ValueError                                Traceback (most recent call last)
# c:\git\python0tohero\section7-milestone-project-1.ipynb Cell 2 in <cell line: 1>()
# ----> <a href='vscode-notebook-cell:/c%3A/git/python0tohero/section7-milestone-project-1.ipynb#ch0000001?line=0'>1</a> result = int(input(print("Choose index position: "))) #print is just so it displays "input" text inline for VSCode.
#       <a href='vscode-notebook-cell:/c%3A/git/python0tohero/section7-milestone-project-1.ipynb#ch0000001?line=1'>2</a> print(result)
#       <a href='vscode-notebook-cell:/c%3A/git/python0tohero/section7-milestone-project-1.ipynb#ch0000001?line=2'>3</a> print(type(result))
#
# ValueError: invalid literal for int() with base 10: 'andrew'

# %%
# validation of input

def user_choice():
    choice = "wrong"
    acceptable_range = range(0,10)
    within_range = False

    while choice.isdigit() == False or within_range == False:
        choice = input(print("Please enter a number (1-10): "))

        if choice.isdigit() == False:
            print("Sorry that is not a digit!")
        
        if choice.isdigit() == True:  # if choice.isdigit() - implies "if true"
            if int(choice) in acceptable_range:
                within_range = True
            else: 
                print("Not in range")
                within_range = False


    return int(choice)

user_choice()
# Out:
# Please enter a number (1-10):
# 2

# %%
def display_game(game_list):
    print("Here is the current game list: ")
    print(game_list)

def position_choice():
    choice = 'wrong'
    choice_range = ['0', '1', '2']
    while choice not in choice_range:

        choice = input(print("Pick a position (0,1,2): "))

        if choice not in choice_range:
            print("Sorry, invalid choice")

    return int(choice) 

def replacement_choice(game_list, position):

    user_placement = input(print("Type a string to place at position"))

    game_list[position] = user_placement

    return game_list

def game_on_choice():
    choice = 'wrong'
    game_modes = ['Y', 'N']
    while choice not in game_modes:

        choice = input(print("Keep playing? ")).upper()

        if choice not in game_modes:
            print("Sorry, invalid choice")

    if choice.upper() == 'Y':
        return True
    else:
        return False


game_on = True
game_list = [0,1,2]

while game_on:
    display_game(game_list)
    position = position_choice()
    game_list = replacement_choice(game_list, position)
    display_game(game_list)
    game_on = game_on_choice()



display_game(game_list)
position_choice()
replacement_choice(game_list, 1)
game_on_choice()
# Out:
# Here is the current game list:
# [0, 1, 2]
# Pick a position (0,1,2):
# Type a string to place at position
# Here is the current game list:
# [0, 1, 'yes']
# Keep playing?
# Here is the current game list:
# [0, 1, 'yes']
# Pick a position (0,1,2):
# Type a string to place at position
# Here is the current game list:
# [0, 'no', 'yes']
# Keep playing?
# Here is the current game list:
# [0, 'no', 'yes']
# Pick a position (0,1,2):
# Sorry, invalid choice
# Pick a position (0,1,2):
# Sorry, invalid choice
# Pick a position (0,1,2):
# Sorry, invalid choice
# Pick a position (0,1,2):
# Sorry, invalid choice
# Pick a position (0,1,2):
# Sorry, invalid choice
# Pick a position (0,1,2):
# Type a string to place at position
# ---------------------------------------------------------------------------
# KeyboardInterrupt                         Traceback (most recent call last)
# c:\git\python0tohero\section7-milestone-project-1.ipynb Cell 4' in <cell line: 55>()
# ...

# %%
#from ipynb.fs.full.includes import *
# import sys 
# import os
# sys.path.append(os.path.abspath("C:\git\python0tohero\milestone_project_1")) #C:\git\python0tohero\milestone_project_1
# import includes
from IPython.display import clear_output


def display_board(board):
    clear_output()
    print('     |     |     ')
    print('  '+ str(board[0][0]) + '  |  ' + str(board[0][1]) + '  |  ' + str(board[0][2]) + '  ')
    print('     |     |     ')
    print('=================')
    print('     |     |     ')
    print('  '+ board[1][0] + '  |  ' + board[1][1] + '  |  ' + board[1][2] + '  ')
    print('     |     |     ')
    print('=================')
    print('     |     |     ')
    print('  '+ board[2][0] + '  |  ' + board[2][1] + '  |  ' + board[2][2] + '  ')
    print('     |     |     ')



test_board = ['#','x','o','x','o','x','o','x','o','x']
board = [[' ',' ',' '], 
         [' ',' ',' '], 
         [' ',' ',' ']]
print(test_board)
test_board = [item.upper() for item in test_board]
print(test_board)


# display_board moved to include file
#display_board(board)



player1 = None
player2 = None
currentplayer = None


def playerattributes():
    xoro = ''
    xoro2 = ''
    player1 = {"name": '', "assignment": ''}
    player2 = {"name": '', "assignment": ''}

    player1name = input(print("What is player 1's name?: "))
    while xoro not in ['X', 'O']:
        xoro = input(print("Will you be X or O?")).upper()
        if xoro not in ['X', 'O']:
            print("Invalid input, try again")
    xoro = xoro.upper()
    
    if xoro == 'X':
        xoro2 = 'O'
    else:
        xoro2 = 'X'

    player2name = input(print("What is player 2's name?: "))
    
    player1["name"], player1["assignment"], player2["name"], player2["assignment"] = player1name, xoro, player2name, xoro2
    print(player1)
    print(player2)

    whosefirst = int(input(print("Who is going first? Enter \"1\" or \"2\": ")))
    currentplayer = ''
    if whosefirst == 1:
        currentplayer = player1
    else:
        currentplayer = player2
    print(f'Alright {currentplayer["name"]}, you are assigned "{currentplayer["assignment"]}" and it\'s your turn!')
    print('enter the number correcponding with your move: ')
    print('1 | 2 | 3')
    print('---------')    
    print('4 | 5 | 6')
    print('---------')    
    print('7 | 8 | 9')
    return currentplayer, player1, player2


# playerattributes()
# playerattributes() moved to includes file
# "32we" <- coding assistance was provided by the cat

currentplayer, player1, player2 = playerattributes() 
print("current player:")
print(currentplayer)

def justwent(player):
    mademove = None
    if player == player1:
        mademove == player1
        currentplayer = player2
    else:
        mademove == player2
        currentplayer = player1
    return mademove, currentplayer



def player_input(currentplayer):
    playerinput = 0
    playerinput = int(input(print("Enter your move:"))) ## need to validate
    if playerinput not in range(1, 10):
        print("Invalid Input")
        playerinput = int(input(print("Enter your move:"))) ## need to validate
    else: 
        if playerinput in range(1,4):
            board[0][playerinput-1] = currentplayer["assignment"]
        if playerinput in range(4,7):
            board[1][playerinput-4] = currentplayer["assignment"]
        if playerinput in range(7,10):
            board[2][playerinput-7] = currentplayer["assignment"]
    return board

    # return display_board(board)



# has anybody won or is the board full

COLUMN_COUNT = 3
ROW_COUNT = 3

def checkwinner(board, piece): 
    if True:
    #Horizontal winner
        for col in range(COLUMN_COUNT-1):
            for row in range(ROW_COUNT-1):
                if board[col][row] == piece and board[col+1][row] == piece and board[col+2][row] == piece:
                    return True

    #Vertical winner
        for col in range(COLUMN_COUNT-1):
            for row in range(ROW_COUNT-1):
                if board[col][row] == piece and board[col][row+1] == piece and board[col][row+2] == piece:
                    return True

    #Diagonal winners
        for col in range(COLUMN_COUNT-1):
            for row in range(ROW_COUNT-1):
                if board[col][row] == piece and board[col+1][row+1] == piece and board[col+2][row+2] == piece:
                    return True

        for col in range(COLUMN_COUNT-1):
            for row in range(ROW_COUNT-1):
                if board[col][row] == piece and board[col+1][row-1] == piece and board[col+2][row-2] == piece:
                    return True
    else: 
        return False


def playgame(board, currentplayer):
    winner = False
    while winner == False:
        player_input(currentplayer)
        clear_output()
        display_board(board)
        if checkwinner(board, currentplayer["assignment"]) == True:
            print("You won!")
        else: 
            currentplayer = justwent(currentplayer)
    

playgame(board, currentplayer)

# def keep_playing():
    

#     clear_output()
#     currentplayer = justwent(currentplayer)
#     print(f"it's {currentplayer['name']}'s turn")








# how to handle game repeats, alternate players or player who won goes first? 
# which player is assigned x or o?
# replay? or "edit profile (rewrite dictionary of player profile)"
# Out:
#      |     |
#   X  |     |
#      |     |
# ...
#      |     |
#      |     |
#      |     |
# ...
#      |     |
#      |     |
#      |     |
# Enter your move:
# ---------------------------------------------------------------------------
# TypeError                                 Traceback (most recent call last)
# c:\git\python0tohero\milestone_project_1\section7-milestone-project-1.ipynb Cell 8 in <cell line: 167>()
#     <a href='vscode-notebook-cell:/c%3A/git/python0tohero/milestone_project_1/section7-milestone-project-1.ipynb#ch0000007?line=162'>163</a>         else:
#     <a href='vscode-notebook-cell:/c%3A/git/python0tohero/milestone_project_1/section7-milestone-project-1.ipynb#ch0000007?line=163'>164</a>             currentplayer = justwent(currentplayer)
# --> <a href='vscode-notebook-cell:/c%3A/git/python0tohero/milestone_project_1/section7-milestone-project-1.ipynb#ch0000007?line=166'>167</a> playgame(board, currentplayer)
#
# ...

# %%
x = range(1)
for n in x: 
    print(n)
# Out:
# 0

# %%
temp123 = 0

while 1 == 1:
    temp123 = 1
    break

#print(temp123)
# Out:
# 1

# %%
#while 1 == 1:

yield(5)
# Out:
#   Input In [30]
#     yield(5)
#     ^
# SyntaxError: 'yield' outside function

# %%
test_list = [0,1,2,3,4,5,6,7,8]
new_list = []
for i in test_list:
    while i % 2 == 0:
        new_list.append(i)
        break
print(new_list)
# Out:
# [0, 2, 4, 6, 8]

# %%
type(currentplayer)
# Out:
# tuple

# %%
def playerattributes():
    # xoro = ''
    # xoro2 = ''
    player1 = {"name": '', "assignment": ''}
    player2 = {"name": '', "assignment": ''}

    # player1name = input(print("What is player 1's name?: "))
    # while xoro not in ['X', 'O']:
    #     xoro = input(print("Will you be X or O?")).upper()
    #     if xoro not in ['X', 'O']:
    #         print("Invalid input, try again")
    # xoro = xoro.upper()
    
    # if xoro == 'X':
    #     xoro2 = 'O'
    # else:
    #     xoro2 = 'X'

    # player2name = input(print("What is player 2's name?: "))
    #///////////////////// DEBUGGING
    player1name = "A"
    xoro = "X"
    player2name = "L"
    xoro2 = "O"

    #////////////////////// /DEBUGGING

    player1["name"], player1["assignment"], player2["name"], player2["assignment"] = player1name, xoro, player2name, xoro2
    print(player1)
    print(player2)

    #whosefirst = int(input(print("Who is going first? Enter \"1\" or \"2\": ")))
    
    #///////////////////// DEBUGGING
    whosefirst = 1
    #///////////////////// /DEBUGGING

    currentplayer = ''
    if whosefirst == 1:
        currentplayer = player1
    else:
        currentplayer = player2
    print(f'Alright {currentplayer["name"]}, you are assigned "{currentplayer["assignment"]}" and it\'s your turn!')
    print('enter the number correcponding with your move: ')
    print('1 | 2 | 3')
    print('---------')    
    print('4 | 5 | 6')
    print('---------')    
    print('7 | 8 | 9')
    return currentplayer, player1, player2

currentplayer, player1, player2 = playerattributes() 

print(currentplayer)
print(type(currentplayer))
print(player1)
print(player2)

def justwent(player):
    mademove = None
    if player == player1:
        mademove = player1
        currentplayer = player2
    else:
        mademove = player2
        currentplayer = player1
    return mademove, currentplayer

currentplayer = justwent(currentplayer)
#justwent(currentplayer)
print(currentplayer)
type(currentplayer)
# Out:
# {'name': 'A', 'assignment': 'X'}
# {'name': 'L', 'assignment': 'O'}
# Alright A, you are assigned "X" and it's your turn!
# enter the number correcponding with your move:
# 1 | 2 | 3
# ---------
# 4 | 5 | 6
# ---------
# 7 | 8 | 9
# {'name': 'A', 'assignment': 'X'}
# <class 'dict'>
# {'name': 'A', 'assignment': 'X'}
# {'name': 'L', 'assignment': 'O'}
# ({'name': 'A', 'assignment': 'X'}, {'name': 'L', 'assignment': 'O'})
# tuple

# %%
test = 1

def testoutput(input):
    if test == 1:
        answer = 2
    return test
    return answer

type(testoutput(test))
print(testoutput(test))
# Out:
# 1

# %%
#refactoring Tic Tac Toe 

from IPython.display import clear_output

theboard = [[' ',' ',' '], 
            [' ',' ',' '], 
            [' ',' ',' ']]

def board_reset(board):
    board = [[' ',' ',' '], 
            [' ',' ',' '], 
            [' ',' ',' ']]

def display_board(board):
    clear_output()
    print('     |     |     ')
    print('  '+ str(board[0][0]) + '  |  ' + str(board[0][1]) + '  |  ' + str(board[0][2]) + '  ')
    print('     |     |     ')
    print('=================')
    print('     |     |     ')
    print('  '+ board[1][0] + '  |  ' + board[1][1] + '  |  ' + board[1][2] + '  ')
    print('     |     |     ')
    print('=================')
    print('     |     |     ')
    print('  '+ board[2][0] + '  |  ' + board[2][1] + '  |  ' + board[2][2] + '  ')
    print('     |     |     ')

player1 = None
player2 = None
currentplayer = None


def playerattributes():
    xoro = ''
    xoro2 = ''
    player1 = {"name": '', "assignment": ''}
    player2 = {"name": '', "assignment": ''}

    player1name = input(print("What is player 1's name?: "))
    while xoro not in ['X', 'O']:
        xoro = input(print("Will you be X or O?")).upper()
        if xoro not in ['X', 'O']:
            print("Invalid input, try again")
    xoro = xoro.upper()
    
    if xoro == 'X':
        xoro2 = 'O'
    else:
        xoro2 = 'X'

    player2name = input(print("What is player 2's name?: "))
    
    player1["name"], player1["assignment"], player2["name"], player2["assignment"] = player1name, xoro, player2name, xoro2
    print(player1)
    print(player2)

    whosefirst = int(input(print("Who is going first? Enter \"1\" or \"2\": ")))
    currentplayer = ''
    if whosefirst == 1:
        currentplayer = player1
    else:
        currentplayer = player2
    print(f'Alright {currentplayer["name"]}, you are assigned "{currentplayer["assignment"]}" and it\'s your turn!')
    print('enter the number correcponding with your move: ')
    print('1 | 2 | 3')
    print('---------')    
    print('4 | 5 | 6')
    print('---------')    
    print('7 | 8 | 9')
    return currentplayer, player1, player2

currentplayer, player1, player2 = playerattributes() 
print(type(currentplayer))
# Switch players when one player moves 

def justwent(player):
    player = player2 if player == player1 else player1
    return player
    
    # mademove = None
    # if player == player1:
    #     mademove == player1
    #     currentplayer = player2
    # else:
    #     mademove == player2
    #     currentplayer = player1
    # return mademove, currentplayer

print(type(currentplayer))

def player_input():
    playerinput = 0
    playerinput = int(input(print("Enter your move:"))) ## need to validate
    if playerinput not in range(1, 10):
        print("Invalid Input")
        playerinput = int(input(print("Enter your move:"))) ## need to validate
    return playerinput


def assign_input_to_board(input, currentplayer):
    
    if input in range(1,4):
            theboard[0][input-1] = currentplayer["assignment"]
    if input in range(4,7):
            theboard[1][input-4] = currentplayer["assignment"]
    if input in range(7,10):
            theboard[2][input-7] = currentplayer["assignment"]



COLUMN_COUNT = 3
ROW_COUNT = 3

def checkwinner(board, piece): 
    if True:
    #Horizontal winner
        for col in range(1):
            for row in range(ROW_COUNT-1):
                if board[col][row] == piece and board[col+1][row] == piece and board[col+2][row] == piece:
                    return True

    #Vertical winner
        for col in range(COLUMN_COUNT-1):
            for row in range(1):
                if board[col][row] == piece and board[col][row+1] == piece and board[col][row+2] == piece:
                    return True

    #Diagonal winners
        for col in range(1):
            for row in range(1):
                if board[col][row] == piece and board[col+1][row+1] == piece and board[col+2][row+2] == piece:
                    return True

        for col in range(1):
            for row in range(2,3):
                if board[col][row] == piece and board[col+1][row-1] == piece and board[col+2][row-2] == piece:
                    return True
    else: 
        return False


def playgame(board, currentplayer):
    winner = False
    while winner == False:
        playerinput = player_input()
        assign_input_to_board(playerinput, currentplayer)
        display_board(board)
        if checkwinner(theboard, currentplayer["assignment"]) == True:
            winner = True
        else: 
            currentplayer = justwent(currentplayer)
            # playerinput = player_input()
    return '{name}, You won with {assignment}!".format(name = currentplayer["name"], assignment = currentplayer["assignment"])'


def playagain():
    playagain = None
    playagain = input(print("Play again? Y/N")).upper()
    if playagain == 'Y':
        theboard = board_reset(theboard)
        return True
    elif playagain == 'N':
        return False
    else: 
        print("invalid input")
        playagain = input(print("Play again? Y/N"))
    

def whileplaying():
    playing = True
    while playing == True:
        playgame(theboard, currentplayer)
        playing = playagain()
    print("Goodbye!")

whileplaying()






# #display_board(theboard)
# #playerattributes()
# playerinput = player_input()
# print(type(currentplayer))
# assign_input_to_board(playerinput)
# display_board(theboard)
# print(type(currentplayer))

# currentplayer = justwent(currentplayer)
# print(type(currentplayer))

# player_input()
# assign_input_to_board(playerinput)
# display_board(theboard)
# Out:
#      |     |
#   X  |  X  |  O
#      |     |
# ...
#      |     |
#   X  |  O  |  O
#      |     |
# ...
#      |     |
#   X  |     |
#      |     |
# Play again? Y/N
# invalid input
# Play again? Y/N
# ---------------------------------------------------------------------------
# KeyboardInterrupt                         Traceback (most recent call last)
# c:\git\python0tohero\_milestone_projects\milestone project 1 - tic tac toe\section7-milestone-project-1.ipynb Cell 16 in <cell line: 176>()
#     <a href='vscode-notebook-cell:/c%3A/git/python0tohero/_milestone_projects/milestone%20project%201%20-%20tic%20tac%20toe/section7-milestone-project-1.ipynb#ch0000015?line=172'>173</a>         playing = playagain()
#     <a href='vscode-notebook-cell:/c%3A/git/python0tohero/_milestone_projects/milestone%20project%201%20-%20tic%20tac%20toe/section7-milestone-project-1.ipynb#ch0000015?line=173'>174</a>     print("Goodbye!")
# ...
